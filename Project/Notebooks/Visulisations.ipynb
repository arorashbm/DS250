# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('clean5.csv', delimiter=',')
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#         Unnamed: 0  district  rural  stratum_code  age  marital_status  \
# 0                0        13      1             2   42               3
# 1                1        13      1             2   47               3
# 2                2        13      1             2   32               3
# 3                3        13      1             2   20               3
# 4                4        13      1             2   27               3
# 5                5        13      1             2   29               3
# 6                6        13      1             2   26               3
# 7                7        13      1             2   26               3
# 8                8        13      1             2   30               3
# 9                9        13      1             2   40               3
# 10              10        13      1             2   40               4
# 11              11        13      1             2   47               3
# ...

# %%
sum(data["district"]==13)
# Out:
# 29869

# %%
data["district"] = data["district"].replace([13], "HARIDWAR")

# %%
data["district"]
# Out:
# 0         HARIDWAR
# 1         HARIDWAR
# 2         HARIDWAR
# 3         HARIDWAR
# 4         HARIDWAR
# 5         HARIDWAR
# 6         HARIDWAR
# 7         HARIDWAR
# 8         HARIDWAR
# 9         HARIDWAR
# 10        HARIDWAR
# 11        HARIDWAR
# 12        HARIDWAR
# 13        HARIDWAR
# 14        HARIDWAR
# 15        HARIDWAR
# 16        HARIDWAR
# 17        HARIDWAR
# 18        HARIDWAR
# 19        HARIDWAR
# 20        HARIDWAR
# 21        HARIDWAR
# 22        HARIDWAR
# 23        HARIDWAR
# 24        HARIDWAR
# 25        HARIDWAR
# 26        HARIDWAR
# 27        HARIDWAR
# 28        HARIDWAR
# 29        HARIDWAR
#             ...
# 905947     CHAMOLI
# 905948     CHAMOLI
# 905949     CHAMOLI
# 905950     CHAMOLI
# 905951     CHAMOLI
# 905952     CHAMOLI
# 905953     CHAMOLI
# 905954     CHAMOLI
# 905955     CHAMOLI
# 905956     CHAMOLI
# 905957     CHAMOLI
# 905958     CHAMOLI
# 905959     CHAMOLI
# 905960     CHAMOLI
# 905961     CHAMOLI
# 905962     CHAMOLI
# ...

# %%
data["chew_updated"] = data["chew"]

# %%
data["chew_updated"] = data["chew_updated"].replace([1, 3, 5], "Chew with Tobacco")
data["chew_updated"] = data["chew_updated"].replace([2, 4], "Chew without Tobacco")
data["chew_updated"] = data["chew_updated"].replace([0, 6, 7, 8], 8)

# %%
data["chew_updated"].unique()
# Out:
# array([8, 'Chew with Tobacco', 'Chew without Tobacco'], dtype=object)

# %%
data.to_csv('clean5.csv')

# %%
sum(data["chew_updated"]==1)
# Out:
# 7427

# %%
data["rural"] = data["rural"].replace([2], "Urban")

# %%
data = data.drop(["chew_updated"], axis = 1)

# %%
data["smoke_updated"] = data["smoke"]
data["alcohol_updated"] = data["alcohol"]

# %%
sum(data["smoke"]==4)
# Out:
# 774850
